# %%
import requests

def get_fpl_data():
    base_url = "https://fantasy.premierleague.com/api/bootstrap-static/"
    response = requests.get(base_url)
    data = response.json()
    return data

fpl_data = get_fpl_data()
fpl_data.keys()
# Out:
# dict_keys(['chips', 'events', 'game_settings', 'game_config', 'phases', 'teams', 'total_players', 'element_stats', 'element_types', 'elements'])

# %%
players_data = fpl_data['elements']
teams_data = fpl_data['teams']
players_data
# Out:
# [{'can_transact': True,
#   'can_select': True,
#   'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 154561,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 4,
#   'cost_change_start_fall': -4,
#   'dreamteam_count': 1,
#   'element_type': 1,
#   'ep_next': '5.8',
#   'ep_this': '5.8',
#   'event_points': 1,
#   'first_name': 'David',
#   'form': '4.8',
#   'id': 1,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 59,
#   'photo': '154561.jpg',
#   'points_per_game': '4.8',
#   'removed': False,
#   'second_name': 'Raya Martín',
#   'selected_by_percent': '32.3',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 53,
#   'transfers_in': 2298755,
#   'transfers_in_event': 24974,
#   'transfers_out': 881623,
#   'transfers_out_event': 25724,
#   'value_form': '0.8',
#   'value_season': '9.0',
#   'web_name': 'Raya',
#   'region': 200,
#   'team_join_date': '2024-07-04',
#   'birth_date': '1995-09-15',
#   'has_temporary_code': False,
#   'opta_code': 'p154561',
#   'minutes': 990,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 7,
#   'goals_conceded': 5,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 1,
#   'red_cards': 0,
#   'saves': 16,
#   'bonus': 3,
#   'bps': 210,
#   'influence': '159.8',
#   'creativity': '10.2',
#   'threat': '0.0',
#   'ict_index': '17.0',
#   'clearances_blocks_interceptions': 9,
#   'recoveries': 87,
#   'tackles': 0,
#   'defensive_contribution': 0,
#   'starts': 11,
#   'expected_goals': '0.00',
#   'expected_assists': '0.04',
#   'expected_goal_involvements': '0.04',
#   'expected_goals_conceded': '6.17',
#   'influence_rank': 116,
#   'influence_rank_type': 15,
#   'creativity_rank': 346,
#   'creativity_rank_type': 3,
#   'threat_rank': 739,
#   'threat_rank_type': 86,
#   'ict_index_rank': 250,
#   'ict_index_rank_type': 16,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.0,
#   'saves_per_90': 1.45,
#   'expected_assists_per_90': 0.0,
#   'expected_goal_involvements_per_90': 0.0,
#   'expected_goals_conceded_per_90': 0.56,
#   'goals_conceded_per_90': 0.45,
#   'now_cost_rank': 94,
#   'now_cost_rank_type': 1,
#   'form_rank': 54,
#   'form_rank_type': 2,
#   'points_per_game_rank': 39,
#   'points_per_game_rank_type': 2,
#   'selected_rank': 8,
#   'selected_rank_type': 2,
#   'starts_per_90': 1.0,
#   'clean_sheets_per_90': 0.64,
#   'defensive_contribution_per_90': 0.0},
#  {'can_transact': True,
#   'can_select': True,
#   'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 109745,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': -3,
#   'cost_change_start_fall': 3,
#   'dreamteam_count': 0,
#   'element_type': 1,
#   'ep_next': '1.0',
#   'ep_this': '1.0',
#   'event_points': 0,
#   'first_name': 'Kepa',
#   'form': '0.0',
#   'id': 2,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 42,
#   'photo': '109745.jpg',
#   'points_per_game': '0.0',
#   'removed': False,
#   'second_name': 'Arrizabalaga Revuelta',
#   'selected_by_percent': '0.4',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 0,
#   'transfers_in': 7999,
#   'transfers_in_event': 132,
#   'transfers_out': 60394,
#   'transfers_out_event': 633,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Arrizabalaga',
#   'region': 200,
#   'team_join_date': '2025-07-01',
#   'birth_date': '1994-10-03',
#   'has_temporary_code': False,
#   'opta_code': 'p109745',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'clearances_blocks_interceptions': 0,
#   'recoveries': 0,
#   'tackles': 0,
#   'defensive_contribution': 0,
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 553,
#   'influence_rank_type': 76,
#   'creativity_rank': 538,
#   'creativity_rank_type': 62,
#   'threat_rank': 506,
#   'threat_rank_type': 49,
#   'ict_index_rank': 554,
#   'ict_index_rank_type': 76,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 608,
#   'now_cost_rank_type': 38,
#   'form_rank': 504,
#   'form_rank_type': 68,
#   'points_per_game_rank': 559,
#   'points_per_game_rank_type': 75,
#   'selected_rank': 244,
#   'selected_rank_type': 34,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0,
#   'defensive_contribution_per_90': 0},
#  {'can_transact': True,
#   'can_select': False,
#   'chance_of_playing_next_round': 0,
#   'chance_of_playing_this_round': 0,
#   'code': 463748,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 1,
#   'ep_next': '0.0',
#   'ep_this': '0.0',
#   'event_points': 0,
#   'first_name': 'Karl',
#   'form': '0.0',
#   'id': 3,
#   'in_dreamteam': False,
#   'news': 'Has joined Werder Bremen on loan for the rest of the season.',
#   'news_added': '2025-08-26T13:44:02.357864Z',
#   'now_cost': 40,
#   'photo': '463748.jpg',
#   'points_per_game': '0.0',
#   'removed': False,
#   'second_name': 'Hein',
#   'selected_by_percent': '0.3',
#   'special': False,
#   'squad_number': None,
#   'status': 'u',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 0,
#   'transfers_in': 5545,
#   'transfers_in_event': 0,
#   'transfers_out': 40579,
#   'transfers_out_event': 356,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Hein',
#   'region': 67,
#   'team_join_date': '2020-10-28',
#   'birth_date': '2002-04-13',
#   'has_temporary_code': False,
#   'opta_code': 'p463748',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'clearances_blocks_interceptions': 0,
#   'recoveries': 0,
#   'tackles': 0,
#   'defensive_contribution': 0,
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 517,
#   'influence_rank_type': 63,
#   'creativity_rank': 502,
#   'creativity_rank_type': 49,
#   'threat_rank': 469,
#   'threat_rank_type': 36,
#   'ict_index_rank': 518,
#   'ict_index_rank_type': 63,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 653,
#   'now_cost_rank_type': 61,
#   'form_rank': 467,
#   'form_rank_type': 55,
#   'points_per_game_rank': 524,
#   'points_per_game_rank_type': 62,
#   'selected_rank': 324,
#   'selected_rank_type': 47,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0,
#   'defensive_contribution_per_90': 0},
#  {'can_transact': True,
#   'can_select': True,
#   'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 551221,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 1,
#   'ep_next': '1.0',
#   'ep_this': '1.0',
#   'event_points': 0,
#   'first_name': 'Tommy',
#   'form': '0.0',
#   'id': 4,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 40,
#   'photo': '551221.jpg',
#   'points_per_game': '0.0',
#   'removed': False,
#   'second_name': 'Setford',
#   'selected_by_percent': '0.2',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 0,
#   'transfers_in': 15698,
#   'transfers_in_event': 128,
#   'transfers_out': 16916,
#   'transfers_out_event': 329,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Setford',
#   'region': 241,
#   'team_join_date': '2024-07-24',
#   'birth_date': '2006-03-13',
#   'has_temporary_code': False,
#   'opta_code': 'p551221',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'clearances_blocks_interceptions': 0,
#   'recoveries': 0,
#   'tackles': 0,
#   'defensive_contribution': 0,
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 534,
#   'influence_rank_type': 72,
#   'creativity_rank': 519,
#   'creativity_rank_type': 58,
#   'threat_rank': 487,
#   'threat_rank_type': 45,
#   'ict_index_rank': 535,
#   'ict_index_rank_type': 72,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 677,
#   'now_cost_rank_type': 70,
#   'form_rank': 485,
#   'form_rank_type': 64,
#   'points_per_game_rank': 541,
#   'points_per_game_rank_type': 71,
#   'selected_rank': 359,
#   'selected_rank_type': 54,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0,
#   'defensive_contribution_per_90': 0},
#  {'can_transact': True,
#   'can_select': True,
#   'chance_of_playing_next_round': 100,
#   'chance_of_playing_this_round': 100,
#   'code': 226597,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 6,
#   'cost_change_start_fall': -6,
#   'dreamteam_count': 3,
#   'element_type': 2,
#   'ep_next': '9.5',
#   'ep_this': '9.5',
#   'event_points': 1,
#   'first_name': 'Gabriel',
#   'form': '8.5',
#   'id': 5,
#   'in_dreamteam': True,
#   'news': '',
#   'news_added': '2025-10-24T14:00:07.880778Z',
#   'now_cost': 66,
#   'photo': '226597.jpg',
#   'points_per_game': '7.4',
#   'removed': False,
#   'second_name': 'dos Santos Magalhães',
#   'selected_by_percent': '43.7',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 81,
#   'transfers_in': 3833770,
#   'transfers_in_event': 59234,
#   'transfers_out': 897587,
#   'transfers_out_event': 11147,
#   'value_form': '1.3',
#   'value_season': '12.3',
#   'web_name': 'Gabriel',
#   'region': 30,
#   'team_join_date': '2020-09-01',
#   'birth_date': '1997-12-19',
#   'has_temporary_code': False,
#   'opta_code': 'p226597',
#   'minutes': 990,
#   'goals_scored': 1,
#   'assists': 2,
#   'clean_sheets': 7,
#   'goals_conceded': 5,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 1,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 13,
#   'bps': 279,
#   'influence': '318.6',
#   'creativity': '62.6',
#   'threat': '88.0',
#   'ict_index': '46.9',
#   'clearances_blocks_interceptions': 88,
#   'recoveries': 15,
#   'tackles': 12,
#   'defensive_contribution': 100,
#   'starts': 11,
#   'expected_goals': '0.82',
#   'expected_assists': '0.69',
#   'expected_goal_involvements': '1.51',
#   'expected_goals_conceded': '6.17',
#   'influence_rank': 8,
#   'influence_rank_type': 3,
#   'creativity_rank': 175,
#   'creativity_rank_type': 43,
#   'threat_rank': 113,
#   'threat_rank_type': 16,
#   'ict_index_rank': 54,
#   'ict_index_rank_type': 10,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.07,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.06,
#   'expected_goal_involvements_per_90': 0.13,
#   'expected_goals_conceded_per_90': 0.56,
#   'goals_conceded_per_90': 0.45,
#   'now_cost_rank': 52,
#   'now_cost_rank_type': 1,
#   'form_rank': 1,
#   'form_rank_type': 1,
#   'points_per_game_rank': 2,
#   'points_per_game_rank_type': 1,
#   'selected_rank': 4,
#   'selected_rank_type': 1,
#   'starts_per_90': 1.0,
#   'clean_sheets_per_90': 0.64,
#   'defensive_contribution_per_90': 9.09},
#  {'can_transact': True,
#   'can_select': True,
#   'chance_of_playing_next_round': 100,
#   'chance_of_playing_this_round': 100,
#   'code': 462424,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 2,
#   'ep_next': '4.5',
#   'ep_this': '4.5',
#   'event_points': 1,
#   'first_name': 'William',
#   'form': '3.5',
#   'id': 6,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': '2025-10-28T21:00:08.018508Z',
#   'now_cost': 60,
#   'photo': '462424.jpg',
#   'points_per_game': '3.9',
#   'removed': False,
#   'second_name': 'Saliba',
#   'selected_by_percent': '11.6',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 39,
#   'transfers_in': 764567,
#   'transfers_in_event': 5892,
#   'transfers_out': 1305029,
#   'transfers_out_event': 12752,
#   'value_form': '0.6',
#   'value_season': '6.5',
#   'web_name': 'Saliba',
#   'region': 73,
#   'team_join_date': '2019-07-25',
#   'birth_date': '2001-03-24',
#   'has_temporary_code': False,
#   'opta_code': 'p462424',
#   'minutes': 724,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 5,
#   'goals_conceded': 3,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 1,
#   'bps': 178,
#   'influence': '169.6',
#   'creativity': '34.1',
#   'threat': '16.0',
#   'ict_index': '22.0',
#   'clearances_blocks_interceptions': 47,
#   'recoveries': 32,
#   'tackles': 10,
#   'defensive_contribution': 57,
#   'starts': 9,
#   'expected_goals': '0.29',
#   'expected_assists': '0.23',
#   'expected_goal_involvements': '0.52',
#   'expected_goals_conceded': '4.65',
#   'influence_rank': 105,
#   'influence_rank_type': 47,
#   'creativity_rank': 250,
#   'creativity_rank_type': 75,
#   'threat_rank': 296,
#   'threat_rank_type': 92,
#   'ict_index_rank': 212,
#   'ict_index_rank_type': 67,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.04,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.03,
#   'expected_goal_involvements_per_90': 0.07,
#   'expected_goals_conceded_per_90': 0.58,
#   'goals_conceded_per_90': 0.37,
#   'now_cost_rank': 86,
#   'now_cost_rank_type': 4,
#   'form_rank': 106,
#   'form_rank_type': 38,
#   'points_per_game_rank': 87,
#   'points_per_game_rank_type': 36,
#   'selected_rank': 37,
#   'selected_rank_type': 12,
#   'starts_per_90': 1.12,
#   'clean_sheets_per_90': 0.62,
#   'defensive_contribution_per_90': 7.09},
#  {'can_transact': True,
#   'can_select': True,
#   'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 466075,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 3,
#   'cost_change_start_fall': -3,
#   'dreamteam_count': 2,
#   'element_type': 2,
#   'ep_next': '5.8',
#   'ep_this': '5.8',
#   'event_points': 1,
#   'first_name': 'Riccardo',
#   'form': '4.8',
#   'id': 7,
#   'in_dreamteam': True,
#   'news': '',
#   'news_added': None,
#   'now_cost': 58,
#   'photo': '466075.jpg',
#   'points_per_game': '5.5',
#   'removed': False,
#   'second_name': 'Calafiori',
#   'selected_by_percent': '16.0',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 61,
#   'transfers_in': 2120707,
#   'transfers_in_event': 13820,
#   'transfers_out': 694938,
#   'transfers_out_event': 25289,
#   'value_form': '0.8',
#   'value_season': '10.5',
#   'web_name': 'Calafiori',
#   'region': 106,
#   'team_join_date': '2024-07-29',
#   'birth_date': '2002-05-19',
#   'has_temporary_code': False,
#   'opta_code': 'p466075',
#   'minutes': 856,
#   'goals_scored': 1,
#   'assists': 2,
#   'clean_sheets': 7,
#   'goals_conceded': 5,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 3,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 3,
#   'bps': 213,
#   'influence': '150.0',
#   'creativity': '89.3',
#   'threat': '181.0',
#   'ict_index': '41.9',
#   'clearances_blocks_interceptions': 34,
#   'recoveries': 42,
#   'tackles': 13,
#   'defensive_contribution': 47,
#   'starts': 11,
#   'expected_goals': '2.24',
#   'expected_assists': '0.25',
#   'expected_goal_involvements': '2.49',
#   'expected_goals_conceded': '4.80',
#   'influence_rank': 131,
#   'influence_rank_type': 57,
#   'creativity_rank': 125,
#   'creativity_rank_type': 26,
#   'threat_rank': 34,
#   'threat_rank_type': 2,
#   'ict_index_rank': 73,
#   'ict_index_rank_type': 17,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.24,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.03,
#   'expected_goal_involvements_per_90': 0.27,
#   'expected_goals_conceded_per_90': 0.5,
#   'goals_conceded_per_90': 0.53,
#   'now_cost_rank': 113,
#   'now_cost_rank_type': 8,
#   'form_rank': 53,
#   'form_rank_type': 18,
#   'points_per_game_rank': 16,
#   'points_per_game_rank_type': 11,
#   'selected_rank': 25,
#   'selected_rank_type': 9,
#   'starts_per_90': 1.16,
#   'clean_sheets_per_90': 0.74,
#   'defensive_contribution_per_90': 4.94},
#  {'can_transact': True,
#   'can_select': True,
#   'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 445122,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 6,
#   'cost_change_start_fall': -6,
#   'dreamteam_count': 2,
#   'element_type': 2,
#   'ep_next': '5.8',
#   'ep_this': '5.8',
#   'event_points': 1,
#   'first_name': 'Jurriën',
#   'form': '4.8',
#   'id': 8,
#   'in_dreamteam': True,
#   'news': '',
#   'news_added': None,
#   'now_cost': 61,
#   'photo': '445122.jpg',
#   'points_per_game': '6.1',
#   'removed': False,
#   'second_name': 'Timber',
#   'selected_by_percent': '25.6',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 67,
#   'transfers_in': 3141328,
#   'transfers_in_event': 24682,
#   'transfers_out': 625237,
#   'transfers_out_event': 33833,
#   'value_form': '0.8',
#   'value_season': '11.0',
#   'web_name': 'J.Timber',
#   'region': 152,
#   'team_join_date': '2023-07-14',
#   'birth_date': '2001-06-17',
#   'has_temporary_code': False,
#   'opta_code': 'p445122',
#   'minutes': 881,
#   'goals_scored': 2,
#   'assists': 2,
#   'clean_sheets': 6,
#   'goals_conceded': 5,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 2,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 7,
#   'bps': 257,
#   'influence': '238.0',
#   'creativity': '179.1',
#   'threat': '216.0',
#   'ict_index': '63.5',
#   'clearances_blocks_interceptions': 27,
#   'recoveries': 33,
#   'tackles': 34,
#   'defensive_contribution': 61,
#   'starts': 10,
#   'expected_goals': '2.08',
#   'expected_assists': '0.64',
#   'expected_goal_involvements': '2.72',
#   'expected_goals_conceded': '5.07',
#   'influence_rank': 42,
#   'influence_rank_type': 17,
#   'creativity_rank': 44,
#   'creativity_rank_type': 8,
#   'threat_rank': 25,
#   'threat_rank_type': 1,
#   'ict_index_rank': 22,
#   'ict_index_rank_type': 1,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.21,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.07,
#   'expected_goal_involvements_per_90': 0.28,
#   'expected_goals_conceded_per_90': 0.52,
#   'goals_conceded_per_90': 0.51,
#   'now_cost_rank': 84,
#   'now_cost_rank_type': 3,
#   'form_rank': 57,
#   'form_rank_type': 19,
#   'points_per_game_rank': 6,
#   'points_per_game_rank_type': 4,
#   'selected_rank': 12,
#   'selected_rank_type': 5,
#   'starts_per_90': 1.02,
#   'clean_sheets_per_90': 0.61,
#   'defensive_contribution_per_90': 6.23},
#  {'can_transact': True,
#   'can_select': False,
#   'chance_of_playing_next_round': 0,
#   'chance_of_playing_this_round': 0,
#   'code': 440854,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': -1,
#   'cost_change_start_fall': 1,
#   'dreamteam_count': 0,
#   'element_type': 2,
#   'ep_next': '0.0',
#   'ep_this': '0.0',
#   'event_points': 0,
#   'first_name': 'Jakub',
#   'form': '0.0',
#   'id': 9,
#   'in_dreamteam': False,
#   'news': 'has joined Porto on loan for the rest of the season.',
#   'news_added': '2025-09-02T13:37:25.929594Z',
#   'now_cost': 54,
#   'photo': '440854.jpg',
#   'points_per_game': '0.0',
#   'removed': False,
#   'second_name': 'Kiwior',
#   'selected_by_percent': '0.1',
#   'special': False,
#   'squad_number': None,
#   'status': 'u',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 0,
#   'transfers_in': 1119,
#   'transfers_in_event': 0,
#   'transfers_out': 10502,
#   'transfers_out_event': 44,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Kiwior',
#   'region': 172,
#   'team_join_date': '2023-01-23',
#   'birth_date': '2000-02-15',
#   'has_temporary_code': False,
#   'opta_code': 'p440854',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'clearances_blocks_interceptions': 0,
#   'recoveries': 0,
#   'tackles': 0,
#   'defensive_contribution': 0,
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 731,
#   'influence_rank_type': 249,
#   'creativity_rank': 730,
#   'creativity_rank_type': 249,
#   'threat_rank': 725,
#   'threat_rank_type': 247,
#   'ict_index_rank': 731,
#   'ict_index_rank_type': 249,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 174,
#   'now_cost_rank_type': 21,
#   'form_rank': 714,
#   'form_rank_type': 246,
#   'points_per_game_rank': 731,
#   'points_per_game_rank_type': 249,
#   'selected_rank': 562,
#   'selected_rank_type': 202,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0,
#   'defensive_contribution_per_90': 0},
#  {'can_transact': True,
#   'can_select': True,
#   'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 499169,
#   'cost_change_event': -1,
#   'cost_change_event_fall': 1,
#   'cost_change_start': -4,
#   'cost_change_start_fall': 4,
#   'dreamteam_count': 0,
#   'element_type': 2,
#   'ep_next': '1.5',
#   'ep_this': '1.5',
#   'event_points': 0,
#   'first_name': 'Myles',
#   'form': '0.5',
#   'id': 10,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 51,
#   'photo': '499169.jpg',
#   'points_per_game': '0.9',
#   'removed': False,
#   'second_name': 'Lewis-Skelly',
#   'selected_by_percent': '1.6',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 6,
#   'transfers_in': 51710,
#   'transfers_in_event': 552,
#   'transfers_out': 357637,
#   'transfers_out_event': 3028,
#   'value_form': '0.1',
#   'value_season': '1.2',
#   'web_name': 'Lewis-Skelly',
#   'region': 241,
#   'team_join_date': '2022-12-04',
#   'birth_date': '2006-09-26',
#   'has_temporary_code': False,
#   'opta_code': 'p499169',
#   'minutes': 86,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 1,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 19,
#   'influence': '9.8',
#   'creativity': '7.2',
#   'threat': '4.0',
#   'ict_index': '2.0',
#   'clearances_blocks_interceptions': 4,
#   'recoveries': 7,
#   'tackles': 1,
#   'defensive_contribution': 5,
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.99',
#   'influence_rank': 391,
#   'influence_rank_type': 144,
#   'creativity_rank': 361,
#   'creativity_rank_type': 124,
#   'threat_rank': 364,
#   'threat_rank_type': 132,
#   'ict_index_rank': 403,
#   'ict_index_rank_type': 141,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.0,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.0,
#   'expected_goal_involvements_per_90': 0.0,
#   'expected_goals_conceded_per_90': 1.04,
#   'goals_conceded_per_90': 0.0,
#   'now_cost_rank': 234,
#   'now_cost_rank_type': 35,
#   'form_rank': 325,
#   'form_rank_type': 108,
#   'points_per_game_rank': 434,
#   'points_per_game_rank_type': 145,
#   'selected_rank': 143,
#   'selected_rank_type': 55,
#   'starts_per_90': 0.0,
#   'clean_sheets_per_90': 0.0,
#   'defensive_contribution_per_90': 5.23},
#  {'can_transact': True,
#   'can_select': True,
#   'chance_of_playing_next_round': 100,
#   'chance_of_playing_this_round': 100,
#   'code': 198869,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': -2,
#   'cost_change_start_fall': 2,
#   'dreamteam_count': 0,
#   'element_type': 2,
#   'ep_next': '1.0',
#   'ep_this': '1.0',
#   'event_points': 0,
#   'first_name': 'Benjamin',
#   'form': '0.0',
#   'id': 11,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': '2025-09-18T04:00:07.778280Z',
#   'now_cost': 53,
#   'photo': '198869.jpg',
#   'points_per_game': '6.0',
#   'removed': False,
#   'second_name': 'White',
#   'selected_by_percent': '0.4',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 6,
#   'transfers_in': 31939,
#   'transfers_in_event': 246,
#   'transfers_out': 93091,
#   'transfers_out_event': 729,
#   'value_form': '0.0',
#   'value_season': '1.1',
#   'web_name': 'White',
#   'region': 241,
#   'team_join_date': '2021-07-30',
#   'birth_date': '1997-10-08',
#   'has_temporary_code': False,
#   'opta_code': 'p198869',
#   'minutes': 70,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 1,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 23,
#   'influence': '15.4',
#   'creativity': '11.3',
#   'threat': '1.0',
#   'ict_index': '2.8',
#   'clearances_blocks_interceptions': 6,
#   'recoveries': 4,
#   'tackles': 2,
#   'defensive_contribution': 8,
#   'starts': 1,
#   'expected_goals': '0.01',
#   'expected_assists': '0.01',
#   'expected_goal_involvements': '0.02',
#   'expected_goals_conceded': '0.87',
#   'influence_rank': 374,
#   'influence_rank_type': 139,
#   'creativity_rank': 340,
#   'creativity_rank_type': 119,
#   'threat_rank': 382,
#   'threat_rank_type': 137,
#   'ict_index_rank': 394,
#   'ict_index_rank_type': 138,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.01,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.01,
#   'expected_goal_involvements_per_90': 0.02,
#   'expected_goals_conceded_per_90': 1.12,
#   'goals_conceded_per_90': 0.0,
#   'now_cost_rank': 195,
#   'now_cost_rank_type': 26,
#   'form_rank': 705,
#   'form_rank_type': 243,
#   'points_per_game_rank': 7,
#   'points_per_game_rank_type': 5,
#   'selected_rank': 266,
#   'selected_rank_type': 100,
#   'starts_per_90': 1.29,
#   'clean_sheets_per_90': 1.29,
#   'defensive_contribution_per_90': 10.29},
#  {'can_transact': True,
#   'can_select': True,
#   'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 563324,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': -1,
#   'cost_change_start_fall': 1,
#   'dreamteam_count': 0,
#   'element_type': 2,
#   'ep_next': '1.0',
#   'ep_this': '1.0',
#   'event_points': 0,
#   'first_name': 'Brayden',
#   'form': '0.0',
#   'id': 13,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 39,
#   'photo': '563324.jpg',
#   'points_per_game': '0.0',
#   'removed': False,
#   'second_name': 'Clarke',
#   'selected_by_percent': '0.4',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 0,
#   'transfers_in': 27829,
#   'transfers_in_event': 141,
#   'transfers_out': 50620,
#   'transfers_out_event': 669,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Clarke',
#   'region': None,
#   'team_join_date': None,
#   'birth_date': None,
#   'has_temporary_code': False,
#   'opta_code': 'p563324',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'clearances_blocks_interceptions': 0,
#   'recoveries': 0,
#   'tackles': 0,
#   'defensive_contribution': 0,
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 477,
#   'influence_rank_type': 181,
#   'creativity_rank': 459,
#   'creativity_rank_type': 179,
#   'threat_rank': 426,
#   'threat_rank_type': 169,
#   'ict_index_rank': 477,
#   'ict_index_rank_type': 180,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 739,
#   'now_cost_rank_type': 237,
#   'form_rank': 426,
#   'form_rank_type': 163,
#   'points_per_game_rank': 483,
#   'points_per_game_rank_type': 180,
#   'selected_rank': 250,
#   'selected_rank_type': 92,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0,
#   'defensive_contribution_per_90': 0},
#  {'can_transact': True,
#   'can_select': False,
#   'chance_of_playing_next_round': 0,
#   'chance_of_playing_this_round': 0,
#   'code': 588793,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': -1,
#   'cost_change_start_fall': 1,
#   'dreamteam_count': 0,
#   'element_type': 2,
#   'ep_next': '0.0',
#   'ep_this': '0.0',
#   'event_points': 0,
#   'first_name': 'Maldini',
#   'form': '0.0',
#   'id': 14,
#   'in_dreamteam': False,
#   'news': 'has joined Morecambe on loan for the rest of the season.',
#   'news_added': '2025-09-22T21:14:30.857843Z',
#   'now_cost': 39,
#   'photo': '588793.jpg',
#   'points_per_game': '0.0',
#   'removed': False,
#   'second_name': 'Kacurri',
#   'selected_by_percent': '0.1',
#   'special': False,
#   'squad_number': None,
#   'status': 'u',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 0,
#   'transfers_in': 10218,
#   'transfers_in_event': 0,
#   'transfers_out': 19727,
#   'transfers_out_event': 207,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Kacurri',
#   'region': None,
#   'team_join_date': None,
#   'birth_date': None,
#   'has_temporary_code': False,
#   'opta_code': 'p588793',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'clearances_blocks_interceptions': 0,
#   'recoveries': 0,
#   'tackles': 0,
#   'defensive_contribution': 0,
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 481,
#   'influence_rank_type': 184,
#   'creativity_rank': 463,
#   'creativity_rank_type': 182,
#   'threat_rank': 430,
#   'threat_rank_type': 172,
#   'ict_index_rank': 481,
#   'ict_index_rank_type': 183,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 744,
#   'now_cost_rank_type': 241,
#   'form_rank': 430,
#   'form_rank_type': 166,
#   'points_per_game_rank': 487,
#   'points_per_game_rank_type': 183,
#   'selected_rank': 431,
#   'selected_rank_type': 158,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0,
#   'defensive_contribution_per_90': 0},
#  {'can_transact': True,
#   'can_select': True,
#   'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 499167,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': -1,
#   'cost_change_start_fall': 1,
#   'dreamteam_count': 0,
#   'element_type': 2,
#   'ep_next': '1.0',
#   'ep_this': '1.0',
#   'event_points': 0,
#   'first_name': 'Josh',
#   'form': '0.0',
#   'id': 15,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 39,
#   'photo': '499167.jpg',
#   'points_per_game': '0.0',
#   'removed': False,
#   'second_name': 'Nichols',
#   'selected_by_percent': '0.2',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 0,
#   'transfers_in': 13162,
#   'transfers_in_event': 34,
#   'transfers_out': 18068,
#   'transfers_out_event': 269,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Nichols',
#   'region': 241,
#   'team_join_date': '2024-07-24',
#   'birth_date': '2006-07-26',
#   'has_temporary_code': False,
#   'opta_code': 'p499167',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'clearances_blocks_interceptions': 0,
#   'recoveries': 0,
#   'tackles': 0,
#   'defensive_contribution': 0,
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 465,
#   'influence_rank_type': 170,
#   'creativity_rank': 447,
#   'creativity_rank_type': 168,
#   'threat_rank': 413,
#   'threat_rank_type': 157,
#   'ict_index_rank': 465,
#   'ict_index_rank_type': 169,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 725,
#   'now_cost_rank_type': 224,
#   'form_rank': 413,
#   'form_rank_type': 151,
#   'points_per_game_rank': 471,
#   'points_per_game_rank_type': 169,
#   'selected_rank': 372,
#   'selected_rank_type': 133,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0,
#   'defensive_contribution_per_90': 0},
#  {'can_transact': True,
#   'can_select': True,
#   'chance_of_playing_next_round': 100,
#   'chance_of_playing_this_round': 100,
#   'code': 223340,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 1,
#   'cost_change_start_fall': -1,
#   'dreamteam_count': 1,
#   'element_type': 3,
#   'ep_next': '7.2',
#   'ep_this': '7.2',
#   'event_points': 12,
#   'first_name': 'Bukayo',
#   'form': '6.2',
#   'id': 16,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': '2025-08-23T22:30:05.759392Z',
#   'now_cost': 101,
#   'photo': '223340.jpg',
#   'points_per_game': '5.0',
#   'removed': False,
#   'second_name': 'Saka',
#   'selected_by_percent': '17.3',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 45,
#   'transfers_in': 2255595,
#   'transfers_in_event': 46090,
#   'transfers_out': 2000425,
#   'transfers_out_event': 18435,
#   'value_form': '0.6',
#   'value_season': '4.5',
#   'web_name': 'Saka',
#   'region': 241,
#   'team_join_date': '2018-11-28',
#   'birth_date': '2001-09-05',
#   'has_temporary_code': False,
#   'opta_code': 'p223340',
#   'minutes': 681,
#   'goals_scored': 3,
#   'assists': 0,
#   'clean_sheets': 5,
#   'goals_conceded': 3,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 5,
#   'bps': 152,
#   'influence': '194.2',
#   'creativity': '257.3',
#   'threat': '229.0',
#   'ict_index': '68.0',
#   'clearances_blocks_interceptions': 4,
#   'recoveries': 41,
#   'tackles': 12,
#   'defensive_contribution': 57,
#   'starts': 8,
#   'expected_goals': '2.41',
#   'expected_assists': '2.26',
#   'expected_goal_involvements': '4.67',
#   'expected_goals_conceded': '4.43',
#   'influence_rank': 81,
#   'influence_rank_type': 28,
#   'creativity_rank': 17,
#   'creativity_rank_type': 17,
#   'threat_rank': 18,
#   'threat_rank_type': 11,
#   'ict_index_rank': 16,
#   'ict_index_rank_type': 11,
#   'corners_and_indirect_freekicks_order': 1,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': 4,
#   'direct_freekicks_text': '',
#   'penalties_order': 1,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.32,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.3,
#   'expected_goal_involvements_per_90': 0.62,
#   'expected_goals_conceded_per_90': 0.59,
#   'goals_conceded_per_90': 0.4,
#   'now_cost_rank': 5,
#   'now_cost_rank_type': 3,
#   'form_rank': 16,
#   'form_rank_type': 6,
#   'points_per_game_rank': 35,
#   'points_per_game_rank_type': 10,
#   'selected_rank': 22,
#   'selected_rank_type': 8,
#   'starts_per_90': 1.06,
#   'clean_sheets_per_90': 0.66,
#   'defensive_contribution_per_90': 7.53},
#  {'can_transact': True,
#   'can_select': True,
#   'chance_of_playing_next_round': 0,
#   'chance_of_playing_this_round': 0,
#   'code': 184029,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': -2,
#   'cost_change_start_fall': 2,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '0.0',
#   'ep_this': '0.0',
#   'event_points': 0,
#   'first_name': 'Martin',
#   'form': '0.0',
#   'id': 17,
#   'in_dreamteam': False,
#   'news': 'Knee injury - Expected back 23 Nov',
#   'news_added': '2025-10-04T20:00:07.945438Z',
#   'now_cost': 78,
#   'photo': '184029.jpg',
#   'points_per_game': '2.2',
#   'removed': False,
#   'second_name': 'Ødegaard',
#   'selected_by_percent': '1.4',
#   'special': False,
#   'squad_number': None,
#   'status': 'i',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 13,
#   'transfers_in': 133232,
#   'transfers_in_event': 70,
#   'transfers_out': 412738,
#   'transfers_out_event': 1444,
#   'value_form': '0.0',
#   'value_season': '1.7',
#   'web_name': 'Ødegaard',
#   'region': 161,
#   'team_join_date': '2021-08-20',
#   'birth_date': '1998-12-17',
#   'has_temporary_code': False,
#   'opta_code': 'p184029',
#   'minutes': 201,
#   'goals_scored': 0,
#   'assists': 1,
#   'clean_sheets': 1,
#   'goals_conceded': 1,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 47,
#   'influence': '43.0',
#   'creativity': '65.0',
#   'threat': '22.0',
#   'ict_index': '13.0',
#   'clearances_blocks_interceptions': 6,
#   'recoveries': 10,
#   'tackles': 3,
#   'defensive_contribution': 19,
#   'starts': 4,
#   'expected_goals': '0.14',
#   'expected_assists': '0.81',
#   'expected_goal_involvements': '0.95',
#   'expected_goals_conceded': '2.36',
#   'influence_rank': 310,
#   'influence_rank_type': 141,
#   'creativity_rank': 171,
#   'creativity_rank_type': 116,
#   'threat_rank': 280,
#   'threat_rank_type': 152,
#   'ict_index_rank': 284,
#   'ict_index_rank_type': 141,
#   'corners_and_indirect_freekicks_order': 3,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': 2,
#   'direct_freekicks_text': '',
#   'penalties_order': 3,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.06,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.36,
#   'expected_goal_involvements_per_90': 0.42,
#   'expected_goals_conceded_per_90': 1.06,
#   'goals_conceded_per_90': 0.45,
#   'now_cost_rank': 19,
#   'now_cost_rank_type': 13,
#   'form_rank': 747,
#   'form_rank_type': 331,
#   'points_per_game_rank': 253,
#   'points_per_game_rank_type': 118,
#   'selected_rank': 155,
#   'selected_rank_type': 53,
#   'starts_per_90': 1.79,
#   'clean_sheets_per_90': 0.45,
#   'defensive_contribution_per_90': 8.51},
#  {'can_transact': True,
#   'can_select': True,
#   'chance_of_playing_next_round': 0,
#   'chance_of_playing_this_round': 0,
#   'code': 248857,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': -2,
#   'cost_change_start_fall': 2,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '0.0',
#   'ep_this': '0.0',
#   'event_points': 0,
#   'first_name': 'Noni',
#   'form': '0.0',
#   'id': 18,
#   'in_dreamteam': False,
#   'news': 'Knee injury - Expected back 23 Nov',
#   'news_added': '2025-09-21T22:30:05.839272Z',
#   'now_cost': 68,
#   'photo': '248857.jpg',
#   'points_per_game': '2.0',
#   'removed': False,
#   'second_name': 'Madueke',
#   'selected_by_percent': '0.6',
#   'special': False,
#   'squad_number': None,
#   'status': 'i',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 10,
#   'transfers_in': 148993,
#   'transfers_in_event': 26,
#   'transfers_out': 226094,
#   'transfers_out_event': 671,
#   'value_form': '0.0',
#   'value_season': '1.5',
#   'web_name': 'Madueke',
#   'region': 241,
#   'team_join_date': '2025-07-18',
#   'birth_date': '2002-03-10',
#   'has_temporary_code': False,
#   'opta_code': 'p248857',
#   'minutes': 304,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 2,
#   'goals_conceded': 2,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 39,
#   'influence': '30.2',
#   'creativity': '111.7',
#   'threat': '105.0',
#   'ict_index': '24.6',
#   'clearances_blocks_interceptions': 1,
#   'recoveries': 10,
#   'tackles': 3,
#   'defensive_contribution': 14,
#   'starts': 4,
#   'expected_goals': '0.29',
#   'expected_assists': '0.86',
#   'expected_goal_involvements': '1.15',
#   'expected_goals_conceded': '2.04',
#   'influence_rank': 335,
#   'influence_rank_type': 152,
#   'creativity_rank': 94,
#   'creativity_rank_type': 71,
#   'threat_rank': 87,
#   'threat_rank_type': 51,
#   'ict_index_rank': 190,
#   'ict_index_rank_type': 102,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.09,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.25,
#   'expected_goal_involvements_per_90': 0.34,
#   'expected_goals_conceded_per_90': 0.6,
#   'goals_conceded_per_90': 0.59,
#   'now_cost_rank': 44,
#   'now_cost_rank_type': 28,
#   'form_rank': 741,
#   'form_rank_type': 328,
#   'points_per_game_rank': 284,
#   'points_per_game_rank_type': 129,
#   'selected_rank': 225,
#   'selected_rank_type': 77,
#   'starts_per_90': 1.18,
#   'clean_sheets_per_90': 0.59,
#   'defensive_contribution_per_90': 4.14},
#  {'can_transact': True,
#   'can_select': True,
#   'chance_of_playing_next_round': 25,
#   'chance_of_playing_this_round': 25,
#   'code': 444145,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': -2,
#   'cost_change_start_fall': 2,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '0.4',
#   'ep_this': '0.4',
#   'event_points': 0,
#   'first_name': 'Gabriel',
#   'form': '0.5',
#   'id': 19,
#   'in_dreamteam': False,
#   'news': 'Muscle injury - 25% chance of playing',
#   'news_added': '2025-10-28T21:00:08.076588Z',
#   'now_cost': 68,
#   'photo': '444145.jpg',
#   'points_per_game': '2.0',
#   'removed': False,
#   'second_name': 'Martinelli Silva',
#   'selected_by_percent': '0.9',
#   'special': False,
#   'squad_number': None,
#   'status': 'd',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 16,
#   'transfers_in': 91420,
#   'transfers_in_event': 28,
#   'transfers_out': 172498,
#   'transfers_out_event': 3371,
#   'value_form': '0.1',
#   'value_season': '2.4',
#   'web_name': 'Martinelli',
#   'region': 30,
#   'team_join_date': '2019-07-15',
#   'birth_date': '2001-06-18',
#   'has_temporary_code': False,
#   'opta_code': 'p444145',
#   'minutes': 214,
#   'goals_scored': 1,
#   'assists': 0,
#   'clean_sheets': 1,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 1,
#   'bps': 56,
#   'influence': '51.0',
#   'creativity': '30.6',
#   'threat': '93.0',
#   'ict_index': '17.5',
#   'clearances_blocks_interceptions': 3,
#   'recoveries': 10,
#   'tackles': 3,
#   'defensive_contribution': 16,
#   'starts': 2,
#   'expected_goals': '0.75',
#   'expected_assists': '0.08',
#   'expected_goal_involvements': '0.83',
#   'expected_goals_conceded': '1.97',
#   'influence_rank': 294,
#   'influence_rank_type': 133,
#   'creativity_rank': 266,
#   'creativity_rank_type': 157,
#   'threat_rank': 105,
#   'threat_rank_type': 65,
#   'ict_index_rank': 247,
#   'ict_index_rank_type': 123,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.32,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.03,
#   'expected_goal_involvements_per_90': 0.35,
#   'expected_goals_conceded_per_90': 0.83,
#   'goals_conceded_per_90': 0.0,
#   'now_cost_rank': 45,
#   'now_cost_rank_type': 29,
#   'form_rank': 338,
#   'form_rank_type': 166,
#   'points_per_game_rank': 285,
#   'points_per_game_rank_type': 130,
#   'selected_rank': 190,
#   'selected_rank_type': 64,
#   'starts_per_90': 0.84,
#   'clean_sheets_per_90': 0.42,
#   'defensive_contribution_per_90': 6.73},
#  {'can_transact': True,
#   'can_select': True,
#   'chance_of_playing_next_round': 100,
#   'chance_of_playing_this_round': 100,
#   'code': 116216,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': -1,
#   'cost_change_start_fall': 1,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '8.0',
#   'ep_this': '8.0',
#   'event_points': 9,
#   'first_name': 'Leandro',
#   'form': '7.0',
#   'id': 20,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': '2025-08-29T18:30:07.885490Z',
#   'now_cost': 69,
#   'photo': '116216.jpg',
#   'points_per_game': '4.4',
#   'removed': False,
#   'second_name': 'Trossard',
#   'selected_by_percent': '0.8',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 40,
#   'transfers_in': 84242,
#   'transfers_in_event': 15447,
#   'transfers_out': 39019,
# ...
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 542,
#   'now_cost_rank_type': 71,
#   'form_rank': 556,
#   'form_rank_type': 56,
#   'points_per_game_rank': 601,
#   'points_per_game_rank_type': 61,
#   'selected_rank': 132,
#   'selected_rank_type': 19,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0,
#   'defensive_contribution_per_90': 0},
#  {'can_transact': True,
#   'can_select': True,
#   'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 230376,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': -4,
#   'cost_change_start_fall': 4,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '1.2',
#   'ep_this': '1.2',
#   'event_points': 0,
#   'first_name': 'Jhon',
#   'form': '1.2',
#   'id': 663,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 51,
#   'photo': '230376.jpg',
#   'points_per_game': '1.9',
#   'removed': False,
#   'second_name': 'Arias',
#   'selected_by_percent': '0.2',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 20,
#   'team_code': 39,
#   'total_points': 19,
#   'transfers_in': 12491,
#   'transfers_in_event': 34,
#   'transfers_out': 66916,
#   'transfers_out_event': 428,
#   'value_form': '0.2',
#   'value_season': '3.7',
#   'web_name': 'J.Arias',
#   'region': 48,
#   'team_join_date': '2025-07-24',
#   'birth_date': '1997-09-21',
#   'has_temporary_code': False,
#   'opta_code': 'p230376',
#   'minutes': 545,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 1,
#   'goals_conceded': 10,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 1,
#   'bps': 90,
#   'influence': '83.4',
#   'creativity': '153.9',
#   'threat': '80.0',
#   'ict_index': '31.7',
#   'clearances_blocks_interceptions': 12,
#   'recoveries': 26,
#   'tackles': 24,
#   'defensive_contribution': 62,
#   'starts': 7,
#   'expected_goals': '1.17',
#   'expected_assists': '0.35',
#   'expected_goal_involvements': '1.52',
#   'expected_goals_conceded': '6.98',
#   'influence_rank': 228,
#   'influence_rank_type': 96,
#   'creativity_rank': 60,
#   'creativity_rank_type': 46,
#   'threat_rank': 122,
#   'threat_rank_type': 75,
#   'ict_index_rank': 128,
#   'ict_index_rank_type': 69,
#   'corners_and_indirect_freekicks_order': 1,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.19,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.06,
#   'expected_goal_involvements_per_90': 0.25,
#   'expected_goals_conceded_per_90': 1.15,
#   'goals_conceded_per_90': 1.65,
#   'now_cost_rank': 232,
#   'now_cost_rank_type': 144,
#   'form_rank': 252,
#   'form_rank_type': 120,
#   'points_per_game_rank': 289,
#   'points_per_game_rank_type': 133,
#   'selected_rank': 368,
#   'selected_rank_type': 126,
#   'starts_per_90': 1.16,
#   'clean_sheets_per_90': 0.17,
#   'defensive_contribution_per_90': 10.24},
#  {'can_transact': True,
#   'can_select': True,
#   'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 497949,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': -1,
#   'cost_change_start_fall': 1,
#   'dreamteam_count': 0,
#   'element_type': 2,
#   'ep_next': '0.2',
#   'ep_this': '0.2',
#   'event_points': 0,
#   'first_name': 'David',
#   'form': '0.2',
#   'id': 682,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 44,
#   'photo': '497949.jpg',
#   'points_per_game': '1.6',
#   'removed': False,
#   'second_name': 'Møller Wolfe',
#   'selected_by_percent': '0.1',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 20,
#   'team_code': 39,
#   'total_points': 8,
#   'transfers_in': 2686,
#   'transfers_in_event': 10,
#   'transfers_out': 6295,
#   'transfers_out_event': 69,
#   'value_form': '0.0',
#   'value_season': '1.8',
#   'web_name': 'Møller Wolfe',
#   'region': 161,
#   'team_join_date': '2025-08-02',
#   'birth_date': '2002-04-23',
#   'has_temporary_code': False,
#   'opta_code': 'p497949',
#   'minutes': 149,
#   'goals_scored': 0,
#   'assists': 1,
#   'clean_sheets': 0,
#   'goals_conceded': 6,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 15,
#   'influence': '37.0',
#   'creativity': '20.9',
#   'threat': '4.0',
#   'ict_index': '6.3',
#   'clearances_blocks_interceptions': 6,
#   'recoveries': 5,
#   'tackles': 2,
#   'defensive_contribution': 8,
#   'starts': 2,
#   'expected_goals': '0.00',
#   'expected_assists': '0.15',
#   'expected_goal_involvements': '0.15',
#   'expected_goals_conceded': '3.62',
#   'influence_rank': 324,
#   'influence_rank_type': 121,
#   'creativity_rank': 299,
#   'creativity_rank_type': 98,
#   'threat_rank': 359,
#   'threat_rank_type': 129,
#   'ict_index_rank': 355,
#   'ict_index_rank_type': 120,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.0,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.09,
#   'expected_goal_involvements_per_90': 0.09,
#   'expected_goals_conceded_per_90': 2.19,
#   'goals_conceded_per_90': 3.62,
#   'now_cost_rank': 533,
#   'now_cost_rank_type': 129,
#   'form_rank': 355,
#   'form_rank_type': 125,
#   'points_per_game_rank': 319,
#   'points_per_game_rank_type': 115,
#   'selected_rank': 536,
#   'selected_rank_type': 192,
#   'starts_per_90': 1.21,
#   'clean_sheets_per_90': 0.0,
#   'defensive_contribution_per_90': 4.83},
#  {'can_transact': True,
#   'can_select': True,
#   'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 523705,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 2,
#   'ep_next': '1.2',
#   'ep_this': '1.2',
#   'event_points': 3,
#   'first_name': 'Jackson',
#   'form': '1.2',
#   'id': 695,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 45,
#   'photo': '523705.jpg',
#   'points_per_game': '1.4',
#   'removed': False,
#   'second_name': 'Tchatchoua',
#   'selected_by_percent': '0.0',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 20,
#   'team_code': 39,
#   'total_points': 14,
#   'transfers_in': 2482,
#   'transfers_in_event': 30,
#   'transfers_out': 2026,
#   'transfers_out_event': 46,
#   'value_form': '0.3',
#   'value_season': '3.1',
#   'web_name': 'Tchatchoua',
#   'region': 38,
#   'team_join_date': '2025-08-19',
#   'birth_date': '2001-09-14',
#   'has_temporary_code': False,
#   'opta_code': 'p523705',
#   'minutes': 517,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 15,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 17,
#   'influence': '118.8',
#   'creativity': '93.5',
#   'threat': '18.0',
#   'ict_index': '23.0',
#   'clearances_blocks_interceptions': 32,
#   'recoveries': 26,
#   'tackles': 11,
#   'defensive_contribution': 43,
#   'starts': 4,
#   'expected_goals': '0.26',
#   'expected_assists': '0.10',
#   'expected_goal_involvements': '0.36',
#   'expected_goals_conceded': '9.18',
#   'influence_rank': 174,
#   'influence_rank_type': 70,
#   'creativity_rank': 118,
#   'creativity_rank_type': 23,
#   'threat_rank': 289,
#   'threat_rank_type': 89,
#   'ict_index_rank': 201,
#   'ict_index_rank_type': 65,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.05,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.02,
#   'expected_goal_involvements_per_90': 0.07,
#   'expected_goals_conceded_per_90': 1.6,
#   'goals_conceded_per_90': 2.61,
#   'now_cost_rank': 444,
#   'now_cost_rank_type': 95,
#   'form_rank': 246,
#   'form_rank_type': 81,
#   'points_per_game_rank': 338,
#   'points_per_game_rank_type': 121,
#   'selected_rank': 652,
#   'selected_rank_type': 224,
#   'starts_per_90': 0.7,
#   'clean_sheets_per_90': 0.0,
#   'defensive_contribution_per_90': 7.49},
#  {'can_transact': True,
#   'can_select': True,
#   'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 431248,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 2,
#   'ep_next': '1.2',
#   'ep_this': '1.2',
#   'event_points': 1,
#   'first_name': 'Ladislav',
#   'form': '1.2',
#   'id': 709,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 45,
#   'photo': '431248.jpg',
#   'points_per_game': '2.1',
#   'removed': False,
#   'second_name': 'Krejcí',
#   'selected_by_percent': '0.1',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 20,
#   'team_code': 39,
#   'total_points': 17,
#   'transfers_in': 9398,
#   'transfers_in_event': 47,
#   'transfers_out': 4864,
#   'transfers_out_event': 149,
#   'value_form': '0.3',
#   'value_season': '3.8',
#   'web_name': 'Krejčí',
#   'region': 57,
#   'team_join_date': '2025-08-28',
#   'birth_date': '1999-04-20',
#   'has_temporary_code': False,
#   'opta_code': 'p431248',
#   'minutes': 720,
#   'goals_scored': 1,
#   'assists': 1,
#   'clean_sheets': 0,
#   'goals_conceded': 17,
#   'own_goals': 1,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 1,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 64,
#   'influence': '208.0',
#   'creativity': '75.2',
#   'threat': '112.0',
#   'ict_index': '39.6',
#   'clearances_blocks_interceptions': 47,
#   'recoveries': 25,
#   'tackles': 10,
#   'defensive_contribution': 57,
#   'starts': 8,
#   'expected_goals': '0.91',
#   'expected_assists': '1.01',
#   'expected_goal_involvements': '1.92',
#   'expected_goals_conceded': '10.83',
#   'influence_rank': 70,
#   'influence_rank_type': 31,
#   'creativity_rank': 148,
#   'creativity_rank_type': 34,
#   'threat_rank': 75,
#   'threat_rank_type': 9,
#   'ict_index_rank': 87,
#   'ict_index_rank_type': 26,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.11,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.13,
#   'expected_goal_involvements_per_90': 0.24,
#   'expected_goals_conceded_per_90': 1.35,
#   'goals_conceded_per_90': 2.12,
#   'now_cost_rank': 419,
#   'now_cost_rank_type': 87,
#   'form_rank': 245,
#   'form_rank_type': 80,
#   'points_per_game_rank': 258,
#   'points_per_game_rank_type': 91,
#   'selected_rank': 553,
#   'selected_rank_type': 197,
#   'starts_per_90': 1.0,
#   'clean_sheets_per_90': 0.0,
#   'defensive_contribution_per_90': 7.12},
#  {'can_transact': True,
#   'can_select': True,
#   'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 488213,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 4,
#   'ep_next': '0.8',
#   'ep_this': '0.8',
#   'event_points': 0,
#   'first_name': 'Tolu',
#   'form': '0.8',
#   'id': 720,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 55,
#   'photo': '488213.jpg',
#   'points_per_game': '1.3',
#   'removed': False,
#   'second_name': 'Arokodare',
#   'selected_by_percent': '0.1',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 20,
#   'team_code': 39,
#   'total_points': 9,
#   'transfers_in': 15496,
#   'transfers_in_event': 165,
#   'transfers_out': 11038,
#   'transfers_out_event': 271,
#   'value_form': '0.1',
#   'value_season': '1.6',
#   'web_name': 'Tolu',
#   'region': 157,
#   'team_join_date': '2025-09-01',
#   'birth_date': '2000-11-23',
#   'has_temporary_code': False,
#   'opta_code': 'p488213',
#   'minutes': 208,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 8,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 25,
#   'influence': '13.4',
#   'creativity': '16.4',
#   'threat': '71.0',
#   'ict_index': '9.8',
#   'clearances_blocks_interceptions': 8,
#   'recoveries': 3,
#   'tackles': 1,
#   'defensive_contribution': 12,
#   'starts': 2,
#   'expected_goals': '0.41',
#   'expected_assists': '0.03',
#   'expected_goal_involvements': '0.44',
#   'expected_goals_conceded': '3.00',
#   'influence_rank': 383,
#   'influence_rank_type': 37,
#   'creativity_rank': 318,
#   'creativity_rank_type': 35,
#   'threat_rank': 138,
#   'threat_rank_type': 29,
#   'ict_index_rank': 317,
#   'ict_index_rank_type': 32,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.18,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.01,
#   'expected_goal_involvements_per_90': 0.19,
#   'expected_goals_conceded_per_90': 1.3,
#   'goals_conceded_per_90': 3.46,
#   'now_cost_rank': 150,
#   'now_cost_rank_type': 37,
#   'form_rank': 301,
#   'form_rank_type': 33,
#   'points_per_game_rank': 356,
#   'points_per_game_rank_type': 37,
#   'selected_rank': 558,
#   'selected_rank_type': 74,
#   'starts_per_90': 0.87,
#   'clean_sheets_per_90': 0.0,
#   'defensive_contribution_per_90': 5.19},
#  {'can_transact': True,
#   'can_select': True,
#   'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 647671,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 4,
#   'ep_next': '1.2',
#   'ep_this': '1.2',
#   'event_points': 1,
#   'first_name': 'Mateus',
#   'form': '1.0',
#   'id': 749,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 45,
#   'photo': '647671.jpg',
#   'points_per_game': '1.0',
#   'removed': False,
#   'second_name': 'Mané',
#   'selected_by_percent': '0.0',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 20,
#   'team_code': 39,
#   'total_points': 1,
#   'transfers_in': 410,
#   'transfers_in_event': 410,
#   'transfers_out': 38,
#   'transfers_out_event': 38,
#   'value_form': '0.2',
#   'value_season': '0.2',
#   'web_name': 'Mané',
#   'region': 241,
#   'team_join_date': '2025-02-24',
#   'birth_date': '2007-09-16',
#   'has_temporary_code': False,
#   'opta_code': 'p647671',
#   'minutes': 20,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 1,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 1,
#   'influence': '0.0',
#   'creativity': '10.9',
#   'threat': '0.0',
#   'ict_index': '1.0',
#   'clearances_blocks_interceptions': 0,
#   'recoveries': 0,
#   'tackles': 0,
#   'defensive_contribution': 0,
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.01',
#   'expected_goal_involvements': '0.01',
#   'expected_goals_conceded': '1.37',
#   'influence_rank': 680,
#   'influence_rank_type': 71,
#   'creativity_rank': 341,
#   'creativity_rank_type': 40,
#   'threat_rank': 654,
#   'threat_rank_type': 70,
#   'ict_index_rank': 417,
#   'ict_index_rank_type': 47,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.0,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.04,
#   'expected_goal_involvements_per_90': 0.04,
#   'expected_goals_conceded_per_90': 6.16,
#   'goals_conceded_per_90': 4.5,
#   'now_cost_rank': 489,
#   'now_cost_rank_type': 67,
#   'form_rank': 267,
#   'form_rank_type': 29,
#   'points_per_game_rank': 391,
#   'points_per_game_rank_type': 44,
#   'selected_rank': 721,
#   'selected_rank_type': 83,
#   'starts_per_90': 0.0,
#   'clean_sheets_per_90': 0.0,
#   'defensive_contribution_per_90': 0.0}]
